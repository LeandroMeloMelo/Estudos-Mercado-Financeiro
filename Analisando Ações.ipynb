# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %%
# !pip install yfinance --upgrade --no cache-dir
import yfinance as yf
yf.pdr_override()

# %% [markdown]
# #Obtendo dados do IBOVSPA

# %%
ibov = web.get_data_yahoo('^BVSP')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1993-04-27  24.799999  25.400000  24.500000  24.500000  24.500000       0
# 1993-04-28  24.500000  24.600000  23.700001  24.299999  24.299999       0
# 1993-04-29  24.299999  24.799999  23.700001  23.700001  23.700001       0
# 1993-04-30  23.700001  24.200001  23.700001  24.100000  24.100000       0
# 1993-05-03  24.100000  24.400000  23.799999  24.100000  24.100000       0

# %%
ibov.tail()
# Out:
#                      Open           High  ...      Adj Close    Volume
# Date                                      ...
# 2020-08-12  102176.000000  103116.000000  ...  102118.000000  10114200
# 2020-08-13  102118.000000  103237.000000  ...  100461.000000  10721300
# 2020-08-14  100469.000000  101717.000000  ...  101353.000000   8576300
# 2020-08-17  101348.000000  101689.000000  ...   99595.000000  10816200
# 2020-08-18   99597.007812  102006.101562  ...  101358.007812         0
#
# [5 rows x 6 columns]

# %%
ibov['Close'].plot(figsize=(22,8))
